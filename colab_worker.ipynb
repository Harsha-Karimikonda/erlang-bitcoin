# %% [markdown]
# # Distributed Erlang Bitcoin Miner - Google Colab Worker
#
# This notebook runs Google Colab as a **distributed remote mining worker** connected to your Erlang server.
#
# ### How It Works:
# 1. **Tailscale**: Connects this Colab VM and your Mac into a secure, private mesh network across the internet.
# 2. **Erlang Actor Clustering**: This Colab worker contacts the Boss actor on your Mac, receives work units, mines on Colab CPUs, and sends discovered coins to your Mac.

# %% [markdown]
# ### Step 1: Connect Colab to Tailscale
# Run this cell. It will print a login link. Click it to log in and connect this Colab runtime to your Tailscale network.

# %%
# !curl -fsSL https://tailscale.com/install.sh | sh
# !tailscale up --qr

# %% [markdown]
# ### Step 2: Install Erlang & Clone Repository

# %%
# !apt-get update -qq && apt-get install -y erlang
# !git clone -b dev https://github.com/Harsha-Karimikonda/erlang-bitcoin.git
# %cd erlang-bitcoin
# !chmod +x project1 project1.escript

# %% [markdown]
# ### Step 3: Run Mining Worker
# Replace `YOUR_MAC_TAILSCALE_IP` with your Mac's Tailscale IP (e.g. `100.x.y.z`), then run this cell.
# *(The worker will remain silent while sending all discovered coins to your Mac server).*

# %%
# Replace with your Mac's Tailscale IP address (e.g. 100.115.22.3)
MAC_IP = "YOUR_MAC_TAILSCALE_IP"
# !./project1 {MAC_IP}
